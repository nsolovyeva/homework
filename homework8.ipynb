# %%
import numpy as np
import pandas as pd
from scipy import stats
from scipy.stats import kurtosis
from scipy.stats import skew

import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/Users/msolovyev/Downloads/wine_data.csv')

# %%
corr = data.corr()
corr
# Out:
#                                  Class   Alcohol  Malic acid       Ash  \
# Class                         1.000000 -0.328222    0.437776 -0.049643
# Alcohol                      -0.328222  1.000000    0.094397  0.211545
# Malic acid                    0.437776  0.094397    1.000000  0.164045
# Ash                          -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash             0.517859 -0.310235    0.288500  0.443367
# Magnesium                    -0.209179  0.270798   -0.054575  0.286587
# Total phenols                -0.719163  0.289101   -0.335167  0.128980
# Flavanoids                   -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols          0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins              -0.499130  0.136698   -0.220746  0.009652
# Color intensity               0.265668  0.546364    0.248985  0.258887
# Hue                          -0.617369 -0.071747   -0.561296 -0.074667
# ...

# %%
sns.heatmap(corr, annot=True,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
sns.pairplot(data, vars=['Alcohol', 'Color intensity'],
                 kind='scatter')

# %%
sns.pairplot(data, vars=['Hue', 'Color intensity'],
                 kind='scatter')

# %%
sns.pairplot(data, vars=['Magnesium', 'Flavanoids'],
                 kind='scatter')

# %%
stats.ttest_ind(data['Alcohol'], data['Color intensity'])
# Out:
# Ttest_indResult(statistic=43.14035165349418, pvalue=5.058453794203161e-143)

# %%
stats.ttest_ind(data['Hue'], data['Color intensity'])
# Out:
# Ttest_indResult(statistic=-23.485186398851056, pvalue=3.4178572035256162e-74)

# %%
stats.ttest_ind(data['Magnesium'], data['Flavanoids'])
# Out:
# Ttest_indResult(statistic=91.05337229398933, pvalue=1.0112341765749605e-247)
